# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
year = [2020, 2021, 2022, 2023, 2024]
height = [145, 150, 160, 165, 170]

# %%
plt.plot(year, height)
plt.show()

# %%
plt.plot(year, height, linewidth=3)
plt.show()

# %%
plt.plot(year, height, linewidth=0.5)
plt.show()

# %%
plt.plot(year, height, marker='o')
plt.show()

# %%
plt.plot(year, height, marker='o', linestyle='None')
plt.show()

# %%
plt.plot(year, height, marker='v')
plt.show()

# %%
plt.plot(year, height, marker='v',  markersize=10)
plt.show()

# %%
plt.plot(year, height, marker='X', markersize=10)

# %%
plt.plot(year, height, marker='o', markersize=10, markeredgecolor='red')

# %%
plt.plot(year, height, marker='o', markersize=10, markeredgecolor='red', markerfacecolor='yellow')

# %%
plt.plot(year, height, marker='s', markersize=10, markeredgecolor='red', markerfacecolor='yellow')

# %%
plt.plot(year, height, linestyle='-')

# %%
plt.plot(year, height, linestyle='-.')

# %%
plt.plot(year, height, linestyle=':')

# %%
plt.plot(year, height, linestyle='--')

# %%
plt.plot(year, height, color='pink')

# %%
plt.plot(year, height, color='#FF0000')

# %%
plt.plot(year, height, color='blue')

# %%
plt.plot(year, height, color='g')

# %%
plt.plot(year, height, 'ro--')

# %%
plt.plot(year, height, 'bv:')

# %%
plt.plot(year, height, 'go')

# %%
plt.plot(year, height, color='g', marker='o', linestyle='None')

# %%
plt.plot(year, height, marker='o', ms=20)

# %%
plt.plot(year, height, marker='o', ms=20, c='g', ls='--')

# %%
plt.plot(year, height, marker='o', ms=20, c='g', ls='--', mfc='g', mec='r', mew=2)

# %%
plt.plot(year, height, marker='o', ms=20, c='g', ls='--', mfc='g', mec='r', mew=2, alpha=0.5)

# %%
size = (15, 5)
type(size)
# Out:
# tuple

# %%
plt.figure(figsize=size)
plt.plot(year, height)
plt.show()

# %%
plt.figure(figsize=(5, 7))  #넓이, 높이
plt.plot(year, height)
plt.show()

# %%
plt.figure(figsize=size, dpi=100, facecolor='#A1C3FF')
plt.plot(year, height)
plt.show()

# %%
plt.plot(year, height, marker='o')
for idx, txt in enumerate(height):
    plt.text(year[idx], height[idx] + 0.5, txt, ha='center', color='red')
plt.show()

# %%
plt.plot(year, height, marker='o')
for idx, txt in enumerate(year):
    plt.text(year[idx], height[idx] + 0.5, txt, ha='center', color='red')
plt.show()

# %%
plt.plot(year, height, marker='o')
for idx, txt in enumerate(year):
    plt.text(year[idx], height[idx] + 0.5, txt, ha='center', color='red')
plt.savefig('data/height.png', dpi=200)
