# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('data/score.csv', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
import numpy as np
index = np.arange(df.shape[0])
index
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
w = 0.25
plt.bar(index-w, df['국어'])
plt.bar(index, df['영어'])
plt.bar(index+w, df['수학'])
plt.show()

# %%
w = 0.25
plt.bar(index-w, df['국어'], width=w)
plt.bar(index, df['영어'], width=w)
plt.bar(index+w, df['수학'], width=w)
plt.show()

# %%
w = 0.25
plt.bar(index - w, df['국어'], width=w, label='국어')
plt.bar(index, df['영어'], width=w, label='영어')
plt.bar(index + w, df['수학'], width=w, label='수학')
plt.legend(ncol=3, loc='upper center')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title('학생별 성적')

w = 0.25
plt.bar(index - w, df['국어'], width=w, label='국어')
plt.bar(index, df['영어'], width=w , label='영어')
plt.bar(index + w, df['수학'], width=w, label='수학')
plt.legend(ncol=3, loc='upper center')

plt.xticks(index, df['이름'], rotation=60)
plt.show()

# %%
kor = list(df['국어'])
kor
# Out:
# [90, 40, 80, 40, 15, 80, 55, 100]

# %%
eng = list(df['영어'])
eng
# Out:
# [85, 35, 75, 60, 20, 100, 65, 85]

# %%
mat = list(df['수학'])
mat
# Out:
# [100, 50, 70, 70, 10, 95, 45, 90]

# %%
names = list(df['이름'])
names
# Out:
# ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

# %%
import numpy as np
idx = np.arange(8)
idx
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
import numpy as np
index = np.arange(8)

kor = [90, 40, 80, 40, 15, 80, 55, 100]
eng = [85, 35, 75, 60, 20, 100, 65, 85]
mat = [100, 50, 70, 70, 10, 95, 45, 90]
names = ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

matplotlib.rcParams['font.size'] = 10
plt.figure(figsize=(10, 5))
plt.title('학생별 성적')

w = 0.25
plt.bar(index - w, kor, width=w, label='국어', color='yellow')
plt.bar(index, eng, width=w , label='영어', color='orange')
plt.bar(index + w, mat, width=w, label='수학', color='green')
plt.legend(loc=(1.01, 0.5))
plt.xticks(index, names, rotation=60)


for i in index:
    plt.text(index[i]-w, kor[i]+1, kor[i], ha='center')
    plt.text(index[i], eng[i]+1, eng[i], ha='center')
    plt.text(index[i]+w, mat[i]+1, mat[i], ha='center')
plt.show()

# %%
w = 0.25
plt.bar(index - w, df['수학'], width=w, label='수학')
plt.bar(index, df['과학'], width=w , label='과학')
plt.bar(index + w, df['사회'], width=w, label='사회')
plt.legend(ncol=3, loc=(1.1, 0.5))

plt.xticks(index, df['이름'], rotation=60)

matplotlib.rcParams['font.size'] = 8
for i in index:
    kor = df.iloc[i, 3]
    plt.text(index[i]-w, kor+1, kor, ha='center', c='b')

    eng = df.iloc[i, 4]
    plt.text(index[i], eng+1, eng, ha='center', c='red')

    mat = df.iloc[i, 5]
    plt.text(index[i]+w, mat+1, mat, ha='center', c='green')
plt.show()
