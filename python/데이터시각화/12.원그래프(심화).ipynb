# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
values = [30, 25, 20, 13, 10, 2]
labels =['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
colors = ['#FFADAD','#FFD6A5','#FDFFB6','#CAFFBF','#9BF6FF','#A0C4FF']
explode = [0.02] * 6

# %%
plt.pie(values, labels=labels, colors=colors, explode=explode, autopct='%.1f%%')
plt.legend(loc=(1, 0.5))
plt.show()

# %%
plt.pie(values, labels=labels, colors=colors, 
        explode=explode, autopct='%.1f%%', 
        startangle=90, counterclock=True,
        wedgeprops={'width':0.8})
plt.show()

# %%
plt.pie(values, labels=labels, colors=colors,
        autopct='%.1f%%',
        startangle=90, counterclock=False,
        wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':2})
plt.show()

# %%
def custom_autopct(pct):
    #return '{:.0f}%'.format(pct) if pct >=10 else ''
    return f'{pct:.0f}%' if pct >= 10 else ''

# %%
plt.pie(values, labels=labels, colors=colors,
        autopct=custom_autopct, pctdistance=0.6, 
        startangle=90, counterclock=False,
        wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':1})
plt.savefig('data/pie.png')
plt.show()

# %%
import pandas as pd
df = pd.read_csv('data/score.csv', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.loc['2번', '학교'] = '산북고'
df.loc['8번', '학교'] = '남능고'

# %%
df_group = df.groupby('학교').size()
df_group
# Out:
# 학교
# 남능고    1
# 능남고    2
# 북산고    4
# 산북고    1
# dtype: int64

# %%
values=list(df_group.values)
labels=list(df_group.index)
print(values, labels)
# Out:
# [np.int64(1), np.int64(2), np.int64(4), np.int64(1)] ['남능고', '능남고', '북산고', '산북고']

# %%
wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':5}
plt.pie(values, labels=labels, colors=colors, 
        autopct='%.1f%%', pctdistance=0.7,
        wedgeprops=wedgeprops)
plt.show()

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
df['SW특기'] = df['SW특기'].fillna('없음')

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  산북고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80          없음
# 5번    강백호  북산고  188   15   20   10  35  10          없음
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      Python
# 8번    윤대협  남능고  190  100   85   90  95  95          C#

# %%
df_group = df.groupby('SW특기').size()

# %%
labels = list(df_group.index)
values = list(df_group.values)

# %%
wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':5}
plt.pie(values, labels=labels, colors=colors,
        startangle=90, counterclock=False,
        autopct='%.1f%%', wedgeprops=wedgeprops)
plt.show()

# %%
df_stu = pd.read_csv('data/학생.csv')
df_stu
# Out:
#         학생번호 학생이름 학생학과  학년      생년월일  지도교수
# 0   92414029  서연우   전산   3  73/10/06   228
# 1   92414033  김창덕   전산   4  73/10/26   221
# 2   92514009  이지행   전자   4  73/11/16   311
# 3   92514023  김형명   전자   4  73/08/29   311
# 4   92454018  이원구   건축   3  74/09/30   509
# 5   95454003  이재영   건축   4  76/02/06   509
# 6   95414058  박혜경   전산   4  76/03/12   221
# 7   96414404  김수정   전산   3  77/12/22   228
# 8   92414001  서연우   전산   3  73/10/06   228
# 9   92414002  김창덕   전산   4  73/10/26   228
# 10  92514003  이지행   전자   4  73/11/16   509
# 11  92514004  김형명   통신   4  73/08/29   311
# 12  92454004  이원구   통신   3  74/09/30   509
# 13  95454006  이재영   통신   4  76/02/06   509
# 14  95414007  박혜경   통신   4  76/03/12   228
# 15  96414408  김수정   건축   3  77/12/22   228

# %%
df_pro = pd.read_csv('data/교수.csv')
df_pro
# Out:
#    교수번호 교수이름 교수학과       임용일 교수직급       급여
# 0   221  이병렬   전산  75/04/03  정교수  3000000
# 1   228  이재광   전산  91/09/19  부교수  2500000
# 2   311  강승일   전자  94/06/09  부교수  2300000
# 3   509  오문환   건축  92/10/14  조교수  2000000

# %%
df_merge = pd.merge(df_stu, df_pro, how='inner', left_on='지도교수', right_on='교수번호')
df_merge
# Out:
#         학생번호 학생이름 학생학과  학년      생년월일  지도교수  교수번호 교수이름 교수학과       임용일 교수직급  \
# 0   92414029  서연우   전산   3  73/10/06   228   228  이재광   전산  91/09/19  부교수
# 1   92414033  김창덕   전산   4  73/10/26   221   221  이병렬   전산  75/04/03  정교수
# 2   92514009  이지행   전자   4  73/11/16   311   311  강승일   전자  94/06/09  부교수
# 3   92514023  김형명   전자   4  73/08/29   311   311  강승일   전자  94/06/09  부교수
# 4   92454018  이원구   건축   3  74/09/30   509   509  오문환   건축  92/10/14  조교수
# 5   95454003  이재영   건축   4  76/02/06   509   509  오문환   건축  92/10/14  조교수
# 6   95414058  박혜경   전산   4  76/03/12   221   221  이병렬   전산  75/04/03  정교수
# 7   96414404  김수정   전산   3  77/12/22   228   228  이재광   전산  91/09/19  부교수
# 8   92414001  서연우   전산   3  73/10/06   228   228  이재광   전산  91/09/19  부교수
# 9   92414002  김창덕   전산   4  73/10/26   228   228  이재광   전산  91/09/19  부교수
# 10  92514003  이지행   전자   4  73/11/16   509   509  오문환   건축  92/10/14  조교수
# 11  92514004  김형명   통신   4  73/08/29   311   311  강승일   전자  94/06/09  부교수
# ...

# %%
df_group = df_merge.groupby(['지도교수','교수이름']).size()
df_group
# Out:
# 지도교수  교수이름
# 221   이병렬     2
# 228   이재광     6
# 311   강승일     3
# 509   오문환     5
# dtype: int64

# %%
labels = [f'{name[1]}({name[0]})' for name in df_group.index]
values = df_group.values

# %%
plt.pie(values, labels=labels, colors=colors,
        autopct='%.1f%%', startangle=90, counterclock=False,
        wedgeprops=wedgeprops)

plt.rc('font', size=20)
plt.title('교수별 학생 현황')
plt.show()

# %%
df_group = df_stu.groupby('학생학과').size()

# %%
labels = list(df_group.index)
values = df_group.values
values
# Out:
# array([3, 6, 3, 4])

# %%
wedgeprops={'width':0.7, 'ec':'yellow', 'lw':3}
plt.title('학과별 학생수 현황')
plt.pie(values, labels=labels, colors=colors,
        autopct='%.1f%%', explode=[e*0.03 for e in values],
        startangle=90, counterclock=False,
        wedgeprops=wedgeprops)
plt.show()

# %%
df_cou = pd.read_csv('data/강좌.csv')
df_cou
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원
# 0  C301    파일처리론     3  506   221   100
# 1  C401   데이터베이스     3  414   221    80
# 2  C421     알고리즘     3  510   228    80
# 3  C312     자료구조     2  510   228   100
# 4  E221     논리회로     3  304   311   100
# 5  A109  한국의건축문화     2  101   509   120

# %%
df_enrol = pd.read_csv('data/수강.csv')
df_enrol
# Out:
#     강좌번호      학생번호       신청일    점수
# 0   C401  92414033  98/03/02  85.0
# 1   C301  92414033  98/03/02  80.0
# 2   C421  92414033  98/03/02   NaN
# 3   C401  95414058  98/03/03  90.0
# 4   C301  95414058  98/03/03  80.0
# 5   C312  95414058  98/03/03  80.0
# 6   C401  92514023  98/03/03   NaN
# 7   C301  92514023  98/03/03  70.0
# 8   C301  92414029  98/03/03  90.0
# 9   C421  92414029  98/03/03   NaN
# 10  C312  92414029  98/03/03  70.0
# 11  E221  92414029  98/03/03  75.0
# 12  A109  92414029  98/03/03  90.0
# 13  C301  92514009  98/03/03  70.0
# 14  E221  92514009  98/03/03  85.0
# 15  C301  96414404  98/03/04  75.0
# 16  C401  96414404  98/03/04  75.0
# 17  C421  96414404  98/03/04  75.0
# 18  C312  92454018  98/03/04  90.0
# 19  E221  92454018  98/03/04  90.0
# 20  A109  95454003  98/03/05  85.0
# 21  C301  95454003  98/03/05  83.0
# 22  E221  95454003  98/03/05  75.0

# %%
def count_cou(code):
    filt = df_enrol['강좌번호'] == code
    df = df_enrol[filt]
    return int(df['강좌번호'].count())

# %%
df_cou['수강인원'] = df_cou['강좌번호'].apply(count_cou)
df_cou
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원  수강인원
# 0  C301    파일처리론     3  506   221   100     7
# 1  C401   데이터베이스     3  414   221    80     4
# 2  C421     알고리즘     3  510   228    80     3
# 3  C312     자료구조     2  510   228   100     3
# 4  E221     논리회로     3  304   311   100     4
# 5  A109  한국의건축문화     2  101   509   120     2

# %%
df = df_cou[['강좌이름', '수강인원']]
df
# Out:
#       강좌이름  수강인원
# 0    파일처리론     7
# 1   데이터베이스     4
# 2     알고리즘     3
# 3     자료구조     3
# 4     논리회로     4
# 5  한국의건축문화     2

# %%
labels = df['강좌이름']
values = df['수강인원']

# %%
plt.pie(values, labels=labels, colors=colors,
        startangle=90, counterclock=False,
        autopct='%.1f%%', 
        explode=explode, wedgeprops=wedgeprops)
plt.show()

# %%
df_stu = pd.read_csv('data/학생.csv')
df_stu
# Out:
#         학생번호 학생이름 학생학과  학년      생년월일  지도교수
# 0   92414029  서연우   전산   3  73/10/06   228
# 1   92414033  김창덕   전산   4  73/10/26   221
# 2   92514009  이지행   전자   4  73/11/16   311
# 3   92514023  김형명   전자   4  73/08/29   311
# 4   92454018  이원구   건축   3  74/09/30   509
# 5   95454003  이재영   건축   4  76/02/06   509
# 6   95414058  박혜경   전산   4  76/03/12   221
# 7   96414404  김수정   전산   3  77/12/22   228
# 8   92414001  서연우   전산   3  73/10/06   228
# 9   92414002  김창덕   전산   4  73/10/26   228
# 10  92514003  이지행   전자   4  73/11/16   509
# 11  92514004  김형명   통신   4  73/08/29   311
# 12  92454004  이원구   통신   3  74/09/30   509
# 13  95454006  이재영   통신   4  76/02/06   509
# 14  95414007  박혜경   통신   4  76/03/12   228
# 15  96414408  김수정   건축   3  77/12/22   228
