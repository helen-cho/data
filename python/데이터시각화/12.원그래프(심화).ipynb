# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
values = [30, 25, 20, 13, 10, 2]
labels =['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
colors = ['#FFADAD','#FFD6A5','#FDFFB6','#CAFFBF','#9BF6FF','#A0C4FF']
explode = [0.05] * 6
plt.pie(values, labels=labels, colors=colors, explode=explode,
        autopct='%.1f%%')
plt.show()

# %%
wedgeprops={'width':0.8}
plt.pie(values, labels=labels, colors=colors, explode=explode,
        autopct='%.1f%%',
        wedgeprops=wedgeprops,
        counterclock=True, startangle=90)
plt.show()

# %%
wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':5}
plt.pie(values, labels=labels, colors=colors,
        autopct='%.1f%%',
        wedgeprops=wedgeprops,
        startangle=90, counterclock=False)
plt.show()

# %%
def custom_autopct(pct):
    return '{:.0f}%'.format(pct) if pct >=10 else ''

# %%
plt.pie(values, labels=labels, colors=colors, 
        wedgeprops=wedgeprops, autopct=custom_autopct, startangle=90, counterclock=False, pctdistance=0.7)
plt.show()

# %%
import pandas as pd
df = pd.read_excel('../데이터분석/data/score.xlsx')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df_group = df.groupby('학교').size()
df_group
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
values=list(df_group.values)
labels=list(df_group.index)
print(values, labels)
# Out:
# [np.int64(3), np.int64(5)] ['능남고', '북산고']

# %%
labels
# Out:
# ['능남고', '북산고']

# %%
wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':5}
plt.pie(values, labels=labels, autopct='%.1f%%', wedgeprops=wedgeprops)
plt.show()

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
df['SW특기'] = df['SW특기'].fillna('없음')

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80          없음
# 4   5번  강백호  북산고  188   15   20   10  35  10          없음
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      Python
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df_group = df.groupby('SW특기').size()
df_group
# Out:
# SW특기
# C             1
# C#            1
# Java          1
# Javascript    1
# Python        2
# 없음            2
# dtype: int64

# %%
labels = list(df_group.index)
values = list(df_group.values)
print(labels, values)
# Out:
# ['C', 'C#', 'Java', 'Javascript', 'Python', '없음'] [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(2), np.int64(2)]

# %%
wedgeprops={'width':0.8, 'edgecolor':'w', 'linewidth':5}
plt.pie(values, labels=labels, autopct='%.1f%%', wedgeprops=wedgeprops)
plt.show()
