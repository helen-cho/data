# %%
import pandas as pd
df = pd.read_excel('data/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교'] = df['학교'].replace({'북산고':'산북고'})
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  산북고  197   90   85  100  95  85      Python
# 2번    정대만  산북고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  산북고  187   40   60   70  75  80         NaN
# 5번    강백호  산북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교'].replace({'북산고':'상북고', '능남고':'무슨고'})
# Out:
# 지원번호
# 1번    산북고
# 2번    산북고
# 3번    산북고
# 4번    산북고
# 5번    산북고
# 6번    무슨고
# 7번    무슨고
# 8번    무슨고
# Name: 학교, dtype: object

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  산북고  197   90   85  100  95  85      Python
# 2번    정대만  산북고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  산북고  187   40   60   70  75  80         NaN
# 5번    강백호  산북고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교'].replace({'북산고':'상북고', '능남고':'무슨고'}, inplace=True)
# Out:
# C:\Users\hdcho\AppData\Local\Temp\ipykernel_15652\1093806298.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['학교'].replace({'북산고':'상북고', '능남고':'무슨고'}, inplace=True)

# %%
import pandas as pd
df = pd.read_excel('data/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.replace({'학교':{'북산고':'상북고', '능남고':'무슨고'}}, inplace=True)
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      Python
# 2번    정대만  상북고  184   40   35   50  55  25        Java
# 3번    송태섭  상북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고  202   80  100   95  85  80           C
# 7번    황태산  무슨고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  무슨고  190  100   85   90  95  95          C#

# %%
df['SW특기'].str.lower()
# Out:
# 지원번호
# 1번        python
# 2번          java
# 3번    javascript
# 4번           NaN
# 5번           NaN
# 6번             c
# 7번        python
# 8번            c#
# Name: SW특기, dtype: object

# %%
df['SW특기'] = df['SW특기'].str.lower()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      python
# 2번    정대만  상북고  184   40   35   50  55  25        java
# 3번    송태섭  상북고  168   80   75   70  80  75  javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고  202   80  100   95  85  80           c
# 7번    황태산  무슨고  188   55   65   45  40  35      python
# 8번    윤대협  무슨고  190  100   85   90  95  95          c#

# %%
df['SW특기'] = df['SW특기'].str.upper()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      PYTHON
# 2번    정대만  상북고  184   40   35   50  55  25        JAVA
# 3번    송태섭  상북고  168   80   75   70  80  75  JAVASCRIPT
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고  202   80  100   95  85  80           C
# 7번    황태산  무슨고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  무슨고  190  100   85   90  95  95          C#

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고  197   90   85  100  95  85      Python
# 2번    정대만  상북고  184   40   35   50  55  25        Java
# 3번    송태섭  상북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고  187   40   60   70  75  80         NaN
# 5번    강백호  상북고  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고  202   80  100   95  85  80           C
# 7번    황태산  무슨고  188   55   65   45  40  35      Python
# 8번    윤대협  무슨고  190  100   85   90  95  95          C#

# %%
df['학교'] = df['학교'] + '등학교'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#

# %%
df['총합'] = df['국어'] + df['영어'] + df['수학'] + df['과학'] + df['사회']
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python  455
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java  205
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript  380
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C  440
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python  240
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#  465

# %%
df['결과'] = 'Fail'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python  455  Fail
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C  440  Fail
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python  240  Fail
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#  465  Fail

# %%
df.loc[df['총합'] > 400, '결과'] = 'Pass'
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python  240  Fail
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#  465  Pass

# %%
df.drop(columns=['총합'])
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN  Fail
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C  Pass
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python  Fail
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#  Pass

# %%
df.drop(columns=['총합', '결과'], inplace=True)

# %%
df.drop(columns='SW특기', inplace=True)

# %%
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85
# 2번    정대만  상북고등학교  184   40   35   50  55  25
# 3번    송태섭  상북고등학교  168   80   75   70  80  75
# 4번    서태웅  상북고등학교  187   40   60   70  75  80
# 5번    강백호  상북고등학교  188   15   20   10  35  10
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80
# 7번    황태산  무슨고등학교  188   55   65   45  40  35
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95

# %%
df.drop(index='4번')
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#

# %%
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %%
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#

# %%
df.drop(index=df.index[0:5])
# Out:
#        이름      학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 6번    변덕규  무슨고등학교  202   80  100  95  85  80       C
# 7번    황태산  무슨고등학교  188   55   65  45  40  35  Python
# 8번    윤대협  무슨고등학교  190  100   85  90  95  95      C#

# %%
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#

# %%
filt = df['수학'] < 80
df[filt]
# Out:
#        이름      학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    정대만  상북고등학교  184  40  35  50  55  25        Java
# 3번    송태섭  상북고등학교  168  80  75  70  80  75  Javascript
# 4번    서태웅  상북고등학교  187  40  60  70  75  80         NaN
# 5번    강백호  상북고등학교  188  15  20  10  35  10         NaN
# 7번    황태산  무슨고등학교  188  55  65  45  40  35      Python

# %%
df[filt].index
# Out:
# Index(['2번', '3번', '4번', '5번', '7번'], dtype='object', name='지원번호')

# %%
df.drop(index=df[filt].index)
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85  Python
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80       C
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95      C#

# %%
df.drop(index=df[filt].index, columns=['총합', '결과'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 df.drop(index=df[filt].index, columns=['총합', '결과'])
#
# File c:\Users\hdcho\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 지원번호
# 1번    채치수  상북고등학교  197   90   85  100  95  85      Python  455  Pass
# 2번    정대만  상북고등학교  184   40   35   50  55  25        Java  205  Fail
# 3번    송태섭  상북고등학교  168   80   75   70  80  75  Javascript  380  Fail
# 4번    서태웅  상북고등학교  187   40   60   70  75  80         NaN  325  Fail
# 5번    강백호  상북고등학교  188   15   20   10  35  10         NaN   90  Fail
# 6번    변덕규  무슨고등학교  202   80  100   95  85  80           C  440  Pass
# 7번    황태산  무슨고등학교  188   55   65   45  40  35      Python  240  Fail
# 8번    윤대협  무슨고등학교  190  100   85   90  95  95          C#  465  Pass

# %%
df.loc['9번'] = ['이정환', '해남고등하고', 184, 90, 90, 90, 90, 90, 'Kotlin', 450, 'Pass'] 
df.tail(2)
# Out:
#        이름      학교    키   국어  영어  수학  과학  사회    SW특기   총합    결과
# 지원번호
# 8번    윤대협  무슨고등학교  190  100  85  90  95  95      C#  465  Pass
# 9번    이정환  해남고등하고  184   90  90  90  90  90  Kotlin  450  Pass

# %%
df.loc['4번', 'SW특기'] = 'Python'
df.loc[['4번']]
# Out:
#        이름      학교    키  국어  영어  수학  과학  사회    SW특기   총합    결과
# 지원번호
# 4번    서태웅  상북고등학교  187  40  60  70  75  80  Python  325  Fail

# %%
df.loc['5번', ['학교', 'SW특기']] = ['능남고등학교', 'C']
df.loc[['5번']]
# Out:
#        이름      학교    키  국어  영어  수학  과학  사회 SW특기  총합    결과
# 지원번호
# 5번    강백호  능남고등학교  188  15  20  10  35  10    C  90  Fail

# %%
cols = list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '총합', '결과']

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '총합', '결과'], dtype='object')

# %%
df = df[[cols[-1]] + cols[0:-1]]
df.head()
# Out:
#         결과   이름      학교    키  국어  영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    Pass  채치수  상북고등학교  197  90  85  100  95  85      Python  455
# 2번    Fail  정대만  상북고등학교  184  40  35   50  55  25        Java  205
# 3번    Fail  송태섭  상북고등학교  168  80  75   70  80  75  Javascript  380
# 4번    Fail  서태웅  상북고등학교  187  40  60   70  75  80      Python  325
# 5번    Fail  강백호  능남고등학교  188  15  20   10  35  10           C   90

# %%
df = df[['결과', '이름', '학교']]
df.head()
# Out:
#         결과   이름      학교
# 지원번호
# 1번    Pass  채치수  상북고등학교
# 2번    Fail  정대만  상북고등학교
# 3번    Fail  송태섭  상북고등학교
# 4번    Fail  서태웅  상북고등학교
# 5번    Fail  강백호  능남고등학교

# %%
df.columns = ['Result', 'Name', 'School']
df.head(5)
# Out:
#      Result Name  School
# 지원번호
# 1번     Pass  채치수  상북고등학교
# 2번     Fail  정대만  상북고등학교
# 3번     Fail  송태섭  상북고등학교
# 4번     Fail  서태웅  상북고등학교
# 5번     Fail  강백호  능남고등학교
